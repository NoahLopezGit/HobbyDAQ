# %%
# 6-Point Gravity Calibration for ADXL356CZ
import pandas as pd
import plotly.express as px

# %%
# import data from csv and plot using plotly
df = pd.read_csv('EVAL-ADXL356CZ Examples/data/6pt_gravity_cal.csv')
fig = px.line(df)
fig.show()
